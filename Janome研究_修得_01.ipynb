# %% [markdown]
# <a href="https://colab.research.google.com/github/muratatk/-_CO2-_-_csv01/blob/main/Janome%E7%A0%94%E7%A9%B6_%E4%BF%AE%E5%BE%97_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/Python_Content/')

# %%
# !ls
# Out:
# 2023-03-08_uni-gram.html  newplot.png
# kadai.csv		  output_01.txt
# kadai_keiyousi.txt	  output_02.csv
# kadai_meisi.txt		  アミン_CO2回収_課題_日本語.csv
# kadai.txt		  アミン_CO2回収_課題_日本語.txt
# kadai_zenbun.txt	  アミン＿CO2回収_課題_検索語.csv
# mecab-ipadic-neologd	  アミン_回収_課題_品詞.xlsx
# meisi_kadai_hindo.csv

# %%
#　ドライブ　オープン_クローズ
# https://www.javadrive.jp/python/file/index2.html

f = open('/content/drive/MyDrive/Python_Content/kadai_zenbun.txt', 'r', encoding='UTF-8')

data = f.read()
print(data)

f.close()
# Out:
# ﻿高効率運転を図りつつ、炭酸ガス（例えば、二酸化炭素）を効率良く除去することができるガスタービン装置を提供するＣＯ↓２吸収液を再生するための熱エネルギーと、回収したＣＯ↓２を圧縮する動力とを供給するとともに、高い熱効率を有するＣＯ↓２の回収方法及びそのシステムを提供する大規模二酸化炭素発生源から排出される二酸化炭素を、コンパクトな設備で効率的かつ安価に分離回収する技術を提供する中空糸状多孔膜を用いるガス分離方法及びその装置において、選択性、安定性及びガス分離速度の点ですぐれるとともに、従来の膜分離法と吸収法では達成し得なかったガス分離の大幅な所要エネルギー低減を図る酸性ガス除去装置１００は、希薄溶剤１２２および準希薄溶剤１３２を独立的に生成する２つの再生器１２０、１３０に濃厚溶剤１０６を供給する吸収器１１０を備え、準希薄溶剤１３２は、再生器の一方１３０において、他方の再生器１２０から誘導された熱１４０および／または蒸気２７６を使用して生成される窒素酸化物及び二酸化炭素を含有するガス中から二酸化窒素を効率良く除去することができ、かつ脱炭酸吸収液への窒素酸化物の蓄積を抑制することができる二酸化窒素と二酸化炭素の除去方法及びその装置を提供する煙道ガスから二酸化炭素を除去及び捕捉する方法であって：（ａ）溶媒抽出ゾーン（１）において煙道ガスを溶媒に接触させることにより煙道ガスから二酸化炭素を抽出して二酸化炭素の奪われた煙道ガスを得るステップ；（ｂ）二酸化炭素含有溶媒を溶媒再生温度に加熱しその温度で維持することにより溶媒再生ゾーン（２）内で溶媒を再生して再生溶媒と二酸化炭素流を得るステップ；及び（ｃ）ステップ（ｂ）で得られた二酸化炭素流を水溶液中に分散した２価アルカリ土類金属ケイ酸塩粒子と接触させることにより、鉱物炭酸塩化ゾーン（３）内で二酸化炭素流とケイ酸塩を反応させるステップを含む方法エネルギー効率を一層向上させたＣＯ↓2回収装置及び方法を提供する煙道ガス、天然ガス、水素ガス、合成ガスから、およびその他のプロセスから、ならびに廃ガス流からＣＯ↓2を除去するために用いられる新たな溶媒および方法を提供するガス中のＣＯ↓2又はＨ↓2Ｓ又はその双方の除去を長時間に亙って安定して除去でき、しかも設備の劣化が少ない吸収液を提供する国際特許出願第ＷＯ－００／４８，７０９号に開示されて
# ...

# %%
# !pip install janome
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 39.4 MB/s eta 0:00:00
# ...

# %%
#　一番基本のTokinize（分かち書き）+品詞確定

# https://note.com/kiyo_ai_note/n/ne1fe4f7a4f2a

from janome.tokenizer import Tokenizer
t = Tokenizer()

f = open('/content/drive/MyDrive/Python_Content/kadai_zenbun.txt', 'r', encoding='UTF-8')

text = f.read()

f.close()

for token in t.tokenize(text):
    print(token)

# %%
#　正規化する
#　Unicode正規化（ユニコードせいきか、英語: Unicode normalization）とは、等価な文字や文字の並びを統一的な内部表現に変換することでテキストの比較を容易にする、テキスト正規化処理の一種である

#  https://nanjamonja.net/archives/793

#　便利すぎるjanomeのAnalyzerモジュール【自然言語処理】

from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer
from janome.charfilter import *
from janome.tokenfilter import *


f = open('/content/drive/MyDrive/Python_Content/kadai_zenbun.txt', 'r', encoding='UTF-8')

text = f.read()

f.close()

# Analyzerフレームワークの使い方 https://note.nkmk.me/python-janome-tutorial/


char_filters = [UnicodeNormalizeCharFilter(),
                RegexReplaceCharFilter('<.*?>', '')] #Unicodeを正規化することで表記ゆれを吸収, #正規表現パターンにマッチした文字列を置換

token_filters =[UpperCaseFilter()]  #アルファベット英字を大文字にする→→→全角･半角　大文字･小文字変換には別途str関数がある　https://note.nkmk.me/python-capitalize-lower-upper-title/

# t = Tokenizer()

analyzer = Analyzer(char_filters=char_filters, token_filters=token_filters )

for token_seikika_zumi in analyzer.analyze(text):
  print(token_seikika_zumi)

# %%
#　表層形, 基本形　https://qiita.com/charon/items/661d9a25b2233a9f8da4
