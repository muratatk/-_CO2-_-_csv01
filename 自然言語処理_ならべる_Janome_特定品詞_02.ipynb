# %% [markdown]
# <a href="https://colab.research.google.com/github/muratatk/-_CO2-_-_csv01/blob/main/%E8%87%AA%E7%84%B6%E8%A8%80%E8%AA%9E%E5%87%A6%E7%90%86_%E3%81%AA%E3%82%89%E3%81%B9%E3%82%8B_Janome_%E7%89%B9%E5%AE%9A%E5%93%81%E8%A9%9E_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Python_Content/')

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Python_Content/kadai_All_naraberu_01.csv', encoding="UTF-8")
df
# Out:
#       ID                                             genbun  data
# 0      1  高効率運転を図りつつ、炭酸ガス（例えば、二酸化炭素）を効率良く除去することができるガスタービ...   NaN
# 1      2  二酸化炭素吸収液を再生するための熱エネルギーと、回収した二酸化炭素を圧縮する動力とを供給する...   NaN
# 2      3  大規模二酸化炭素発生源から排出される二酸化炭素を、コンパクトな設備で効率的かつ安価に分離回収...   NaN
# 3      4  中空糸状多孔膜を用いるガス分離方法及びその装置において、選択性、安定性及びガス分離速度の点で...   NaN
# 4      5  酸性ガス除去装置１００は、希薄溶剤１２２および準希薄溶剤１３２を独立的に生成する２つの再生器...   NaN
# ..   ...                                                ...   ...
# 308  309  排ガスに含まれる炭酸ガスを吸収液に吸収させて炭酸ガス含有吸収液を生成する吸収塔と、吸収塔から...   NaN
# 309  310  排ガスに含まれる炭酸ガスを吸収液に吸収させて二酸化炭素含有吸収液を生成する吸収塔と、吸収塔か...   NaN
# 310  311  二酸化炭素を含有する被分離ガス（例えば燃焼排ガス）から二酸化炭素を分離する分離装置（６０）を...   NaN
# 311  312  工場設備から排出される排ガスを有効利用して、排水中のアルカリ土類金属イオンを除去してスケール...   NaN
# 312  313        水素及びアンモニア製造システムに関し、プラントの排水から有価物を効率よく安価に生成する   NaN
#
# [313 rows x 3 columns]

# %%
# https://rinsaka.com/python/hyaku/02-janome.html百人一首　神戸学院大学


df[df.index == 0]
# Out:
#    ID                                             genbun  data
# 0   1  高効率運転を図りつつ、炭酸ガス（例えば、二酸化炭素）を効率良く除去することができるガスタービ...   NaN

# %%
df[df.ID== 1][['ID', 'genbun', 'data']]
# Out:
#    ID                                             genbun  data
# 0   1  高効率運転を図りつつ、炭酸ガス（例えば、二酸化炭素）を効率良く除去することができるガスタービ...   NaN

# %%
genbun = df.loc[:, ['ID','genbun']].values
genbun
# Out:
# array([[1, '高効率運転を図りつつ、炭酸ガス（例えば、二酸化炭素）を効率良く除去することができるガスタービン装置を提供する'],
#        [2,
#         '二酸化炭素吸収液を再生するための熱エネルギーと、回収した二酸化炭素を圧縮する動力とを供給するとともに、高い熱効率を有する二酸化炭素の回収方法及びそのシステムを提供する'],
#        [3, '大規模二酸化炭素発生源から排出される二酸化炭素を、コンパクトな設備で効率的かつ安価に分離回収する技術を提供する'],
#        [4,
#         '中空糸状多孔膜を用いるガス分離方法及びその装置において、選択性、安定性及びガス分離速度の点ですぐれるとともに、従来の膜分離法と吸収法では達成し得なかったガス分離の大幅な所要エネルギー低減を図る'],
#        [5,
#         '酸性ガス除去装置１００は、希薄溶剤１２２および準希薄溶剤１３２を独立的に生成する２つの再生器１２０、１３０に濃厚溶剤１０６を供給する吸収器１１０を備え、準希薄溶剤１３２は、再生器の一方１３０において、他方の再生器１２０から誘導された熱１４０および／または蒸気２７６を使用して生成される'],
#        [6,
#         '窒素酸化物及び二酸化炭素を含有するガス中から二酸化窒素を効率良く除去することができ、かつ脱炭酸吸収液への窒素酸化物の蓄積を抑制することができる二酸化窒素と二酸化炭素の除去方法及びその装置を提供する'],
#        [7,
#         '煙道ガスから二酸化炭素を除去及び捕捉する方法であって：（ａ）溶媒抽出ゾーン（１）において煙道ガスを溶媒に接触させることにより煙道ガスから二酸化炭素を抽出して二酸化炭素の奪われた煙道ガスを得るステップ；（ｂ）二酸化炭素含有溶媒を溶媒再生温度に加熱しその温度で維持することにより溶媒再生ゾーン（２）内で溶媒を再生して再生溶媒と二酸化炭素流を得るステップ；及び（ｃ）ステップ（ｂ）で得られた二酸化炭素流を水溶液中に分散した２価アルカリ土類金属ケイ酸塩粒子と接触させることにより、鉱物炭酸塩化ゾーン（３）内で二酸化炭素流とケイ酸塩を反応させるステップを含む方法'],
# ...

# %%
# !pip install janome
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer
from janome.charfilter import *
from janome.tokenfilter import *

s=genbun[0][1]


t = Tokenizer()

for token in t.tokenize(s):
    print(token)
# Out:
# 高	接頭詞,名詞接続,*,*,*,*,高,コウ,コー
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 運転	名詞,サ変接続,*,*,*,*,運転,ウンテン,ウンテン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 図り	動詞,自立,*,*,五段・ラ行,連用形,図る,ハカリ,ハカリ
# つつ	助詞,接続助詞,*,*,*,*,つつ,ツツ,ツツ
# 、	記号,読点,*,*,*,*,、,、,、
# 炭酸	名詞,一般,*,*,*,*,炭酸,タンサン,タンサン
# ガス	名詞,一般,*,*,*,*,ガス,ガス,ガス
# （	記号,括弧開,*,*,*,*,（,（,（
# 例えば	接続詞,*,*,*,*,*,例えば,タトエバ,タトエバ
# 、	記号,読点,*,*,*,*,、,、,、
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# ）	記号,括弧閉,*,*,*,*,）,）,）
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# 除去	名詞,サ変接続,*,*,*,*,除去,ジョキョ,ジョキョ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# ガス	名詞,一般,*,*,*,*,ガス,ガス,ガス
# タービン	名詞,一般,*,*,*,*,タービン,タービン,タービン
# 装置	名詞,サ変接続,*,*,*,*,装置,ソウチ,ソーチ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 提供	名詞,サ変接続,*,*,*,*,提供,テイキョウ,テイキョー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル

# %%
#　どの品詞がよく出てくるのか、配列を変えて検討

from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer
from janome.charfilter import *
from janome.tokenfilter import *

s=genbun[5][1]


t = Tokenizer()

for token in t.tokenize(s):
    print(token)
# Out:
# 窒素	名詞,一般,*,*,*,*,窒素,チッソ,チッソ
# 酸化	名詞,サ変接続,*,*,*,*,酸化,サンカ,サンカ
# 物	名詞,接尾,一般,*,*,*,物,ブツ,ブツ
# 及び	接続詞,*,*,*,*,*,及び,オヨビ,オヨビ
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 含有	名詞,サ変接続,*,*,*,*,含有,ガンユウ,ガンユー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# ガス	名詞,一般,*,*,*,*,ガス,ガス,ガス
# 中	名詞,接尾,副詞可能,*,*,*,中,チュウ,チュー
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 二	名詞,数,*,*,*,*,二,ニ,ニ
# 酸化	名詞,サ変接続,*,*,*,*,酸化,サンカ,サンカ
# 窒素	名詞,一般,*,*,*,*,窒素,チッソ,チッソ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# 除去	名詞,サ変接続,*,*,*,*,除去,ジョキョ,ジョキョ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# 、	記号,読点,*,*,*,*,、,、,、
# かつ	接続詞,*,*,*,*,*,かつ,カツ,カツ
# 脱	接頭詞,名詞接続,*,*,*,*,脱,ダツ,ダツ
# 炭酸	名詞,一般,*,*,*,*,炭酸,タンサン,タンサン
# 吸収	名詞,サ変接続,*,*,*,*,吸収,キュウシュウ,キューシュー
# 液	名詞,接尾,一般,*,*,*,液,エキ,エキ
# へ	助詞,格助詞,一般,*,*,*,へ,ヘ,エ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 窒素	名詞,一般,*,*,*,*,窒素,チッソ,チッソ
# 酸化	名詞,サ変接続,*,*,*,*,酸化,サンカ,サンカ
# ...

# %%
# https://yu-nix.com/archives/python-janome-ppn/

from janome.tokenizer import Tokenizer

s=genbun[0][1]

t = Tokenizer()

toks = t.tokenize(s)


for tok in toks:
    print(tok.part_of_speech)  # 品詞を出力
# Out:
# 接頭詞,名詞接続,*,*
# 名詞,一般,*,*
# 名詞,サ変接続,*,*
# 助詞,格助詞,一般,*
# 動詞,自立,*,*
# 助詞,接続助詞,*,*
# 記号,読点,*,*
# 名詞,一般,*,*
# 名詞,一般,*,*
# 記号,括弧開,*,*
# 接続詞,*,*,*
# 記号,読点,*,*
# 名詞,一般,*,*
# 記号,括弧閉,*,*
# 助詞,格助詞,一般,*
# 名詞,一般,*,*
# 形容詞,自立,*,*
# 名詞,サ変接続,*,*
# 動詞,自立,*,*
# 名詞,非自立,一般,*
# 助詞,格助詞,一般,*
# 動詞,自立,*,*
# 名詞,一般,*,*
# 名詞,一般,*,*
# 名詞,サ変接続,*,*
# 助詞,格助詞,一般,*
# 名詞,サ変接続,*,*
# 動詞,自立,*,*

# %%
#　名詞だけ取り出せるようにする


from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer

s=genbun[0][1]

token_filters = [POSKeepFilter(['名詞'])]

a = Analyzer(token_filters=token_filters)

for token in a.analyze(s):
    print(token)
# Out:
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 運転	名詞,サ変接続,*,*,*,*,運転,ウンテン,ウンテン
# 炭酸	名詞,一般,*,*,*,*,炭酸,タンサン,タンサン
# ガス	名詞,一般,*,*,*,*,ガス,ガス,ガス
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 除去	名詞,サ変接続,*,*,*,*,除去,ジョキョ,ジョキョ
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# ガス	名詞,一般,*,*,*,*,ガス,ガス,ガス
# タービン	名詞,一般,*,*,*,*,タービン,タービン,タービン
# 装置	名詞,サ変接続,*,*,*,*,装置,ソウチ,ソーチ
# 提供	名詞,サ変接続,*,*,*,*,提供,テイキョウ,テイキョー

# %%
#　名詞','動詞','接頭詞','形容詞を取り出せるようにする


from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer

s=genbun[0][1]

token_filters = [POSKeepFilter(['名詞','動詞','接頭詞','形容詞'])]

a = Analyzer(token_filters=token_filters)

for token in a.analyze(s):
    print(token)
# Out:
# 高	接頭詞,名詞接続,*,*,*,*,高,コウ,コー
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 運転	名詞,サ変接続,*,*,*,*,運転,ウンテン,ウンテン
# 図り	動詞,自立,*,*,五段・ラ行,連用形,図る,ハカリ,ハカリ
# 炭酸	名詞,一般,*,*,*,*,炭酸,タンサン,タンサン
# ガス	名詞,一般,*,*,*,*,ガス,ガス,ガス
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# 除去	名詞,サ変接続,*,*,*,*,除去,ジョキョ,ジョキョ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# ガス	名詞,一般,*,*,*,*,ガス,ガス,ガス
# タービン	名詞,一般,*,*,*,*,タービン,タービン,タービン
# 装置	名詞,サ変接続,*,*,*,*,装置,ソウチ,ソーチ
# 提供	名詞,サ変接続,*,*,*,*,提供,テイキョウ,テイキョー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル

# %%
#　動詞は必要ない。名詞','接頭詞','形容詞を取り出せるようにする


from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer

s=genbun[0][1]

token_filters = [POSKeepFilter(['名詞','接頭詞','形容詞'])]

a = Analyzer(token_filters=token_filters)

for token in a.analyze(s):
    print(token)
# Out:
# 高	接頭詞,名詞接続,*,*,*,*,高,コウ,コー
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 運転	名詞,サ変接続,*,*,*,*,運転,ウンテン,ウンテン
# 炭酸	名詞,一般,*,*,*,*,炭酸,タンサン,タンサン
# ガス	名詞,一般,*,*,*,*,ガス,ガス,ガス
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# 除去	名詞,サ変接続,*,*,*,*,除去,ジョキョ,ジョキョ
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# ガス	名詞,一般,*,*,*,*,ガス,ガス,ガス
# タービン	名詞,一般,*,*,*,*,タービン,タービン,タービン
# 装置	名詞,サ変接続,*,*,*,*,装置,ソウチ,ソーチ
# 提供	名詞,サ変接続,*,*,*,*,提供,テイキョウ,テイキョー

# %%
#　別の列を見る
#　動詞は必要ない。名詞','接頭詞','形容詞を取り出せるようにする


from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer

s=genbun[1][1]

token_filters = [POSKeepFilter(['名詞','接頭詞','形容詞'])]

a = Analyzer(token_filters=token_filters)

for token in a.analyze(s):
    print(token)
# Out:
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# 吸収	名詞,サ変接続,*,*,*,*,吸収,キュウシュウ,キューシュー
# 液	名詞,接尾,一般,*,*,*,液,エキ,エキ
# 再生	名詞,サ変接続,*,*,*,*,再生,サイセイ,サイセイ
# ため	名詞,非自立,副詞可能,*,*,*,ため,タメ,タメ
# 熱	名詞,一般,*,*,*,*,熱,ネツ,ネツ
# エネルギー	名詞,一般,*,*,*,*,エネルギー,エネルギー,エネルギー
# 回収	名詞,サ変接続,*,*,*,*,回収,カイシュウ,カイシュー
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# 圧縮	名詞,サ変接続,*,*,*,*,圧縮,アッシュク,アッシュク
# 動力	名詞,一般,*,*,*,*,動力,ドウリョク,ドーリョク
# 供給	名詞,サ変接続,*,*,*,*,供給,キョウキュウ,キョーキュー
# 高い	形容詞,自立,*,*,形容詞・アウオ段,基本形,高い,タカイ,タカイ
# 熱	名詞,一般,*,*,*,*,熱,ネツ,ネツ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# 回収	名詞,サ変接続,*,*,*,*,回収,カイシュウ,カイシュー
# 方法	名詞,一般,*,*,*,*,方法,ホウホウ,ホーホー
# システム	名詞,一般,*,*,*,*,システム,システム,システム
# 提供	名詞,サ変接続,*,*,*,*,提供,テイキョウ,テイキョー

# %%
#　複合名詞

from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer

s=genbun[5][1]

a = Analyzer(token_filters=[CompoundNounFilter()])

for token in a.analyze(s):
    print(token)
# Out:
# 窒素酸化物	名詞,複合,*,*,*,*,窒素酸化物,チッソサンカブツ,チッソサンカブツ
# 及び	接続詞,*,*,*,*,*,及び,オヨビ,オヨビ
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 含有	名詞,サ変接続,*,*,*,*,含有,ガンユウ,ガンユー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# ガス中	名詞,複合,*,*,*,*,ガス中,ガスチュウ,ガスチュー
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 二酸化窒素	名詞,複合,*,*,*,*,二酸化窒素,ニサンカチッソ,ニサンカチッソ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 効率	名詞,一般,*,*,*,*,効率,コウリツ,コーリツ
# 良く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,良い,ヨク,ヨク
# 除去	名詞,サ変接続,*,*,*,*,除去,ジョキョ,ジョキョ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# でき	動詞,自立,*,*,一段,連用形,できる,デキ,デキ
# 、	記号,読点,*,*,*,*,、,、,、
# かつ	接続詞,*,*,*,*,*,かつ,カツ,カツ
# 脱	接頭詞,名詞接続,*,*,*,*,脱,ダツ,ダツ
# 炭酸吸収液	名詞,複合,*,*,*,*,炭酸吸収液,タンサンキュウシュウエキ,タンサンキューシューエキ
# へ	助詞,格助詞,一般,*,*,*,へ,ヘ,エ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 窒素酸化物	名詞,複合,*,*,*,*,窒素酸化物,チッソサンカブツ,チッソサンカブツ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 蓄積	名詞,サ変接続,*,*,*,*,蓄積,チクセキ,チクセキ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 抑制	名詞,サ変接続,*,*,*,*,抑制,ヨクセイ,ヨクセイ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# ...

# %%
#　複合名詞

from janome.tokenizer import Tokenizer
from janome.analyzer import Analyzer

s=genbun[2][1]

a = Analyzer(token_filters=[CompoundNounFilter()])

for token in a.analyze(s):
    print(token)
# Out:
# 大	接頭詞,名詞接続,*,*,*,*,大,ダイ,ダイ
# 規模二酸化炭素発生源	名詞,複合,*,*,*,*,規模二酸化炭素発生源,キボニサンカタンソハッセイゲン,キボニサンカタンソハッセイゲン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 排出	名詞,サ変接続,*,*,*,*,排出,ハイシュツ,ハイシュツ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# 二酸化炭素	名詞,一般,*,*,*,*,二酸化炭素,ニサンカタンソ,ニサンカタンソ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 、	記号,読点,*,*,*,*,、,、,、
# コンパクト	名詞,形容動詞語幹,*,*,*,*,コンパクト,コンパクト,コンパクト
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 設備	名詞,サ変接続,*,*,*,*,設備,セツビ,セツビ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 効率的	名詞,複合,*,*,*,*,効率的,コウリツテキ,コーリツテキ
# かつ	接続詞,*,*,*,*,*,かつ,カツ,カツ
# 安価	名詞,形容動詞語幹,*,*,*,*,安価,アンカ,アンカ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 分離回収	名詞,複合,*,*,*,*,分離回収,ブンリカイシュウ,ブンリカイシュー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 技術	名詞,一般,*,*,*,*,技術,ギジュツ,ギジュツ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 提供	名詞,サ変接続,*,*,*,*,提供,テイキョウ,テイキョー
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル

# %%
# ChatGPTのコード

from janome.tokenizer import Tokenizer

# 入力テキスト
input_text = "排気ガスの処理方法及び処理装置において、気ガスを冷却して運転コストの増加を抑制すると共に、冷却に使用した処理排液を有効的に使用することで処理コストの増加を抑制する"

# 名詞、接続詞、形容詞、複合名詞の品詞リスト
pos_list = ['名詞', '接続詞', '形容詞', '複合名詞']

# JanomeのTokenizerクラスのインスタンスを作成
t = Tokenizer()

# 入力テキストを形態素に分解し、品詞情報を取得して指定された品詞の単語を抽出
extracted_words = [token.surface for token in t.tokenize(input_text) if token.part_of_speech.split(',')[0] in pos_list]

# 抽出された単語を表示
print(extracted_words)
# Out:
# ['排気', 'ガス', '処理', '方法', '及び', '処理', '装置', '気', 'ガス', '冷却', '運転', 'コスト', '増加', '抑制', '冷却', '使用', '処理', '排', '液', '有効', '的', '使用', 'こと', '処理', 'コスト', '増加', '抑制']

# %%
# ChatGPTのコードで品詞も特定するもの

from janome.tokenizer import Tokenizer

# 入力テキスト
s=genbun[1][1]

input_text = "排気ガスの処理方法及び処理装置において、気ガスを冷却して運転コストの増加を抑制すると共に、冷却に使用した処理排液を有効的に使用することで処理コストの増加を抑制する"

# 名詞、接続詞、形容詞、複合名詞の品詞リスト
pos_list = ['名詞', '接続詞', '形容詞', '複合名詞']

# JanomeのTokenizerクラスのインスタンスを作成
t = Tokenizer()

# 入力テキストを形態素に分解し、品詞情報を取得して指定された品詞の単語を抽出し、二次元配列に格納
extracted_words = []
for token in t.tokenize(input_text):
    if token.part_of_speech.split(',')[0] in pos_list:
        extracted_words.append([token.surface, token.part_of_speech.split(',')[0]])

# 抽出された単語と品詞の二次元配列を表示
for word, pos in extracted_words:
    print("単語: {}, 品詞: {}".format(word, pos))
# Out:
# 単語: 排気, 品詞: 名詞
# 単語: ガス, 品詞: 名詞
# 単語: 処理, 品詞: 名詞
# 単語: 方法, 品詞: 名詞
# 単語: 及び, 品詞: 接続詞
# 単語: 処理, 品詞: 名詞
# 単語: 装置, 品詞: 名詞
# 単語: 気, 品詞: 名詞
# 単語: ガス, 品詞: 名詞
# 単語: 冷却, 品詞: 名詞
# 単語: 運転, 品詞: 名詞
# 単語: コスト, 品詞: 名詞
# 単語: 増加, 品詞: 名詞
# 単語: 抑制, 品詞: 名詞
# 単語: 冷却, 品詞: 名詞
# 単語: 使用, 品詞: 名詞
# 単語: 処理, 品詞: 名詞
# 単語: 排, 品詞: 名詞
# 単語: 液, 品詞: 名詞
# 単語: 有効, 品詞: 名詞
# 単語: 的, 品詞: 名詞
# 単語: 使用, 品詞: 名詞
# 単語: こと, 品詞: 名詞
# 単語: 処理, 品詞: 名詞
# 単語: コスト, 品詞: 名詞
# 単語: 増加, 品詞: 名詞
# 単語: 抑制, 品詞: 名詞

# %%
#

# %%
from janome.analyzer import Analyzer
from janome.tokenfilter import POSKeepFilter
from janome.tokenizer import Tokenizer

# 解析対象の文章
input_text = "大規模二酸化炭素発生源から排出される二酸化炭素を、コンパクトな設備で効率的かつ安価に分離回収する技術を提供する"

# JanomeのTokenizerを用意
t = Tokenizer()

# 名詞、複合名詞、形容詞、接続詞の品詞リスト
pos_list = ['名詞', '名詞,複合', '形容詞', '接続詞']

# 二次元配列に単語とその品詞を格納する
result = [[token.surface, token.part_of_speech] for token in Analyzer(token_filters=[POSKeepFilter(pos_list)], tokenizer=t).analyze(input_text)]

print(result)
# Out:
# [['規模', '名詞,一般,*,*'], ['二酸化炭素', '名詞,一般,*,*'], ['発生', '名詞,サ変接続,*,*'], ['源', '名詞,接尾,一般,*'], ['排出', '名詞,サ変接続,*,*'], ['二酸化炭素', '名詞,一般,*,*'], ['コンパクト', '名詞,形容動詞語幹,*,*'], ['設備', '名詞,サ変接続,*,*'], ['効率', '名詞,一般,*,*'], ['的', '名詞,接尾,形容動詞語幹,*'], ['かつ', '接続詞,*,*,*'], ['安価', '名詞,形容動詞語幹,*,*'], ['分離', '名詞,サ変接続,*,*'], ['回収', '名詞,サ変接続,*,*'], ['技術', '名詞,一般,*,*'], ['提供', '名詞,サ変接続,*,*']]

# %%
from janome.analyzer import Analyzer
from janome.tokenfilter import POSKeepFilter, CompoundNounFilter
from janome.tokenizer import Tokenizer

# 解析対象の文章
input_text = "複数の気体を含むガス状物質から特定ガスのみを選択して分離・回収することができるガス回収方法および装置を提供すること"

# JanomeのTokenizerを用意
t = Tokenizer()

# 名詞、複合名詞、形容詞、接続詞の品詞リスト
pos_list = ['名詞', '名詞,複合', '形容詞', '接続詞']

# 二次元配列に単語とその品詞を格納する
result = [[token.surface, token.part_of_speech] for token in Analyzer(token_filters=[POSKeepFilter(pos_list), CompoundNounFilter()], tokenizer=t).analyze(input_text)]

print(result)
# Out:
# [['複数気体ガス状物質特定ガス選択分離回収ことガス回収方法', '名詞,複合,*,*'], ['および', '接続詞,*,*,*'], ['装置提供こと', '名詞,複合,*,*']]

# %%
# 複合名詞を加えると、長い長い複合名詞になるので省略
#　接続詞もいらない

from janome.analyzer import Analyzer
from janome.tokenfilter import POSKeepFilter
from janome.tokenizer import Tokenizer

# 解析対象の文章
input_text = "排気ガスの処理方法及び処理装置において、気ガスを冷却して運転コストの増加を抑制すると共に、冷却に使用した処理排液を有効的に使用することで処理コストの増加を抑制する"

# JanomeのTokenizerを用意
t = Tokenizer()

# 名詞、形容詞、接続詞の品詞リスト
pos_list = ['名詞', '形容詞']

# 二次元配列に単語とその品詞を格納する
result = [[token.surface, token.part_of_speech] for token in Analyzer(token_filters=[POSKeepFilter(pos_list)], tokenizer=t).analyze(input_text)]

print(result)
# Out:
# [['排気', '名詞,サ変接続,*,*'], ['ガス', '名詞,一般,*,*'], ['処理', '名詞,サ変接続,*,*'], ['方法', '名詞,一般,*,*'], ['処理', '名詞,サ変接続,*,*'], ['装置', '名詞,サ変接続,*,*'], ['気', '名詞,一般,*,*'], ['ガス', '名詞,一般,*,*'], ['冷却', '名詞,サ変接続,*,*'], ['運転', '名詞,サ変接続,*,*'], ['コスト', '名詞,一般,*,*'], ['増加', '名詞,サ変接続,*,*'], ['抑制', '名詞,サ変接続,*,*'], ['冷却', '名詞,サ変接続,*,*'], ['使用', '名詞,サ変接続,*,*'], ['処理', '名詞,サ変接続,*,*'], ['排', '名詞,サ変接続,*,*'], ['液', '名詞,接尾,一般,*'], ['有効', '名詞,形容動詞語幹,*,*'], ['的', '名詞,接尾,形容動詞語幹,*'], ['使用', '名詞,サ変接続,*,*'], ['こと', '名詞,非自立,一般,*'], ['処理', '名詞,サ変接続,*,*'], ['コスト', '名詞,一般,*,*'], ['増加', '名詞,サ変接続,*,*'], ['抑制', '名詞,サ変接続,*,*']]

# %%
#　データフレームの配列で文章を定義
# 複合名詞を加えると、長い長い複合名詞になるので省略
#　接続詞もいらない,形容詞もいらない


from janome.analyzer import Analyzer
from janome.tokenfilter import POSKeepFilter
from janome.tokenizer import Tokenizer

# 解析対象の文章
input_text =genbun[3][1]

# JanomeのTokenizerを用意
t = Tokenizer()

# 名詞、形容詞、接続詞の品詞リスト
pos_list = ['名詞']

# 二次元配列に単語とその品詞を格納する
result = [[token.surface, token.part_of_speech] for token in Analyzer(token_filters=[POSKeepFilter(pos_list)], tokenizer=t).analyze(input_text)]

print(result)
# Out:
# [['中空', '名詞,一般,*,*'], ['糸状', '名詞,一般,*,*'], ['多孔', '名詞,一般,*,*'], ['膜', '名詞,一般,*,*'], ['ガス', '名詞,一般,*,*'], ['分離', '名詞,サ変接続,*,*'], ['方法', '名詞,一般,*,*'], ['装置', '名詞,サ変接続,*,*'], ['選択', '名詞,サ変接続,*,*'], ['性', '名詞,接尾,一般,*'], ['安定', '名詞,形容動詞語幹,*,*'], ['性', '名詞,接尾,一般,*'], ['ガス', '名詞,一般,*,*'], ['分離', '名詞,サ変接続,*,*'], ['速度', '名詞,一般,*,*'], ['点', '名詞,非自立,一般,*'], ['従来', '名詞,副詞可能,*,*'], ['膜', '名詞,一般,*,*'], ['分離', '名詞,サ変接続,*,*'], ['法', '名詞,接尾,一般,*'], ['吸収', '名詞,サ変接続,*,*'], ['法', '名詞,接尾,一般,*'], ['達成', '名詞,サ変接続,*,*'], ['ガス', '名詞,一般,*,*'], ['分離', '名詞,サ変接続,*,*'], ['大幅', '名詞,形容動詞語幹,*,*'], ['所要', '名詞,サ変接続,*,*'], ['エネルギー', '名詞,一般,*,*'], ['低減', '名詞,サ変接続,*,*']]

# %%
#　PythonのJanomeを使ってください。1つのcsvファイルのgenbunという列に複数行の日本語の文章が入っています。この文章から名詞だけを取り出して、取り出した名詞を日本語の文章が入っているgenbunという列のの右側のdataという列に書き込む方法を教えてください。PythonのJanomeを使ってください。1つのcsvファイルのgenbunという列に複数行の日本語の文章が入っています。この文章から名詞だけを取り出して、取り出した名詞を日本語の文章が入っているgenbunという列のの右側のdataという列に書き込む方法を教えてください。

import csv
from janome.analyzer import Analyzer
from janome.tokenizer import Tokenizer

# CSVファイルの読み込み
with open('/content/drive/MyDrive/Python_Content/kadai_All_naraberu_01.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    # CSVファイルのヘッダーを取得
    header = next(reader)
    # 日本語の文章が入っている列のインデックスを取得
    genbun_index = header.index('genbun')
    # 列の数に応じて、名詞を入れる列のインデックスを計算
    noun_index = len(header)
    header.append('data')
    
    # JanomeのTokenizerを用意
    t = Tokenizer()

        # CSVファイルの内容を読み込み、名詞を抽出して書き込み
    rows = []
    for row in reader:
        # 日本語の文章を取得
        input_text = row[genbun_index]
        
        # 名詞を抽出
        nouns = [token.surface for token in t.tokenize(input_text) if token.part_of_speech.startswith('名詞')]
        
        # 取り出した名詞をdata列に書き込む
        row.append(' '.join(nouns))
        rows.append(row)
        
    # CSVファイルに書き込み
    with open('/content/drive/MyDrive/Python_Content/output_kadai_All_naraberu_01.csv', 'w', encoding='utf-8', newline='') as fw:
        writer = csv.writer(fw)
        writer.writerow(header)
        writer.writerows(rows)

# %%
#いよいよnlpolotにとりかかる


df = pd.read_csv('/content/drive/MyDrive/Python_Content/output_kadai_All_naraberu_01.csv')
df

# %%
# !pip install nlplot

# %%
import nlplot
npt = nlplot.NLPlot(df, target_col='data')

npt.bar_ngram(
    title='uni-gram',
    xaxis_label='word_count',
    yaxis_label='word',
    ngram=1,
    top_n=50,
#    stopwords=stopwords,
)

# %%
import nlplot
npt = nlplot.NLPlot(df, target_col='data')

npt.treemap(
    title='Tree of Most Common Words',
    ngram=1,
    top_n=30,
)

# %%
import nlplot
import matplotlib.pyplot as plt

npt = nlplot.NLPlot(df, target_col='data')

npt.wordcloud(
    max_words=100,
    max_font_size=100,
    colormap='tab20_r',
)

fig_wc = npt.wordcloud(
    width=1000,
    height=600,
    max_words=100,
    max_font_size=100,
    colormap='tab20_r',
    mask_file=None,
    save=False
)
plt.figure(figsize=(15, 25))
plt.imshow(fig_wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
npt.word_distribution(
    title='number of words distribution'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ビルド（データ件数によっては処理に時間を要します）※ノードの数のみ変更
npt.build_graph(min_edge_frequency=25)
# Out:
# node_size:29, edge_size:132

# %%
import nlplot

# graph data
display(
    npt.node_df.head(),
    npt.edge_df.head(),
)
# Out:
#     id  id_code  adjacency_frequency  betweeness_centrality  \
# 0   除去        0                   10               0.000000
# 1   吸収        1                   18               0.038636
# 2  排ガス        2                    9               0.005291
# 3    液        3                   13               0.004288
# 4   分離        4                    5               0.000000
#
#    clustering_coefficient  community
# 0                1.000000          0
# 1                0.555556          0
# 2                0.833333          2
# 3                0.846154          0
# 4                1.000000          0
#   source target  edge_frequency  source_code  target_code
# 0  二酸化炭素     提供             161           25           23
# 1  二酸化炭素     回収             158           25           12
# 2     回収     提供             125           12           23
# 3  二酸化炭素     吸収             120           25            1
# 4     提供     方法             114           23           26

# %%
import nlplot
npt.sunburst(
    title='All sentiment sunburst chart',
    colorscale=True,
    color_continuous_scale='Oryel',
    width=1000,
    height=800,
)

# %%
# 共起ネットワークにはplotlyが必要
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#共起ネットワーク図作成 https://blog.since2020.jp/data_analysis/nlplot_questionnaire/
#iplotをインポートして使えば結果が表示される

import nlplot
import matplotlib.pyplot as plt
from plotly.offline import iplot

npt = nlplot.NLPlot(df, target_col='data')

npt.build_graph(min_edge_frequency=8)

fig_co_network = npt.co_network(
title='Co-occurrence network',
sizing=100,
node_size='adjacency_frequency',
color_palette='hls',
width=1100,
height=700,
save=False
)
iplot(fig_co_network)
# Out:
# node_size:102, edge_size:689
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
